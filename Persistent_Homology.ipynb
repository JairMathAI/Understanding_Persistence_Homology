# %% [markdown]
# <center>
# <h1><b>Persistent Homology</b></h1>
# </center>
#
# <center>
# <img src="source/img/0.PNG" width="500" height="200"/>
# </center>
#
# <center>
# <h1><a href="https://link.springer.com/book/10.1007/978-3-319-23488-5">Homotopical Topology Fomenko & Fuchs Springer</a></h1>
# </center>

# %% [markdown]
# <center>
# <h1><b>Homology</b> (A gate between two words) 🌕➡️🌎</h1>
# </center><br><br>
# <center>
# <h1><b>Functor Formal Definition</b></h1>
# </center><br><br>
# <center>
# <h1>Let $\mathscr{C}$ and $\mathscr{D}$ be categories.<br><br>
# A functor $F: \mathscr{C} \to \mathscr{D}$ is a mapping that:<br><br>
# $\forall \hspace{3mm}X \in \text{Obj}(\mathscr{C}),\hspace{4mm} F(X)\in\text{Obj}(\mathscr{D})$<br><br>
# $\forall \hspace{3mm}f \in \text{Morph}(\mathscr{C}),\hspace{4mm} F ( f )\in \text{Morph}(\mathscr{D})$<br><br>
# Such that:<br><br>
# $ F(\mathrm {id} _{X})=\mathrm {id} _{F(X)} \hspace{10mm} \forall\hspace{3mm} X \in \text{Obj}(\mathscr{C})$<br><br>
# ${\displaystyle F(g\circ f)=F(g)\circ F(f)} \hspace{10mm} \forall\hspace{3mm} {\displaystyle f\colon X\to Y\,\!} , {\displaystyle g\colon Y\to Z} \in\text{Morph}(\mathscr{C})$</h1>
#
# </center>
# <br><br>
# <center>
# <img src="source/img/25.PNG" width="1300" height="800"/>
# </center>
# <br><br>
#
# <center>
# <img src="source/img/1.PNG" width="1300" height="800"/>
# </center>
# <br><br>
#
# <center>
# <img src="source/img/26.png" width="500" height="200"/>
# </center>
# <br><br>

# %% [markdown]
# <center>
# <h1><b>Lest cook some Homology!</b>👩🏻‍🍳👨🏻‍🍳</h1>
# <br><br>
#
# <center>
# <h1>Ingredients:📝</h1>
#     <h1>Manifolds</h1>
#     <h1>Triangulations</h1>
#     <h1>Groups</h1>
#     <h1>Functions</h1>
#     <h1>Holes</h1>
#     <h1>Abstract Nonsense 🤣</h1>
# <br><br>

# %% [markdown]
# <center>
# <h1><b>Manifold</b> (Unraveling geometry through Sticky Notes) 🌐➡️🌎</h1>
# </center><br><br>
#
# <center>
# <h1><b>Formal Definition</b></h1>
# </center><br><br>
#
# <center>
# <h2> Hausdorff Second Countable Topology Space $(X,\tau)$ st $\hspace{4mm}\exists\hspace{2mm} n\hspace{2mm}\forall\hspace{2mm} U\in\tau \Rightarrow U\cong U'\subseteq \mathbb{R}^n$</h2>
# </center>
# <br><br>
#
# <center>
# <img src="source/img/3.png" width="1050" height="550"/>
# </center>
# <br><br>
# <br><br>

# %% [markdown]
# <center>
# <img src="source/img/2.png" width="1100" height="600"/>
# </center>
# <br><br>
#
# <center>
# <h1><b>Theorem</b></h1>
# </center><br><br>
#
# <center>
# <h1>Every $n$ Manifold with $n\leqslant 3$ has a triangulation (Rado & Moise)</h1>
# </center><br><br>
#
# <center>
# <h1>Every $n$ Smooth Manifold has a triangulation (Whitehead & Cairns)</h1>
# </center><br><br>

# %% [markdown]
# <center>
# <h1><b>From Shapes to Triangulations</h1>
# </center>
#
# <center>
# <img src="source/img/4.PNG" width="1100" height="6000"/>
# </center>

# %% [markdown]
# <center>
# <h1><b>K-simplicies</b> (Triangles on steroids) 💊</h1>
# </center><br><br>
#
# <center>
# <h1><b>Formal Definition</b></h1>
# </center><br><br>
#
# <center>
# <h2>Is a convex hull of $k + 1$ vertices. Suppose $k + 1$ points ${\displaystyle u_{0},\dots ,u_{k}}$ are affinely independ, ie, ${\displaystyle u_{1}-u_{0},\dots ,u_{k}-u_{0}}$ are linearly independent. </h2>
# <br><br>
# <h2>Then, the simplex determined by them is the set of points</h2>
# </center><br><br>
#
# <center>
# <h2>${\displaystyle C=\left\{\theta _{0}u_{0}+\dots +\theta _{k}u_{k}~{\Bigg |}~\sum _{i=0}^{k}\theta _{i}=1{\mbox{ and }}\theta _{i}\geq 0{\mbox{ for }}i=0,\dots ,k\right\}.}$</h2>
# </center><br><br>
#
# <center>
# <img src="source/img/21.PNG" width="1100" height="600"/>
# </center>
#
# <br><br>
#
# <center>
# <h1><b>Simplicial complex</b> (Buildings Structures) 👷🏻‍♂️👷🏻‍♀️🏗️</h1>
# </center><br><br>
#
# <center>
# <h1><b>Formal Definition</b></h1>
# </center><br><br>
#
# <center>
# <h2>A simplicial complex ${\displaystyle {\mathcal {K}}}$ is a set of simplices that satisfies the following conditions:</h2>
# <br><br>
#
# <h2>Every face of a simplex from  ${\displaystyle {\mathcal {K}}}$ is also in ${\displaystyle {\mathcal {K}}}$.</h2>
# <br><br>
#
# <h2>The non-empty intersection of any two simplices ${\displaystyle \sigma _{1},\sigma _{2}\in {\mathcal {K}}}$ is a face of both ${\displaystyle \sigma _{1}}$ and ${\displaystyle \sigma _{2}}$.</h2>
# <br><br>
# </center>
#
# <center>
# <img src="source/img/5.PNG" width="1100" height="600"/>
# </center>

# %% [markdown]
# <center>
# <h1><b>Computable algorithm</h1>
# </center><br><br>
#
# <center>
# <h1><b>Vietoris-Ribs complex</h1>
# </center><br><br>
#
# <center>
# <h1><b>Formal Definition</b></h1>
# </center><br><br>
#
# <center>
# <h2>Given a metric space $(X,d)$ We can define the Vietoris-Ribs complex as the open cover:</h2>
# </center> <br><br>
#
# <center>
# <h2>$\displaystyle V_{\varepsilon}(X) = \{\sigma\subseteq\ X | \forall \varepsilon\geqslant 0 , u,v\in \sigma : d(u,v)\leqslant \varepsilon\} $</h2>
# </center><br><br>
#
# <center>
# <img src="source/img/6.PNG" width="1100" height="600"/>
# </center>

# %%
import numpy as np
import matplotlib.pyplot as plt
import teaspoon.MakeData.PointCloud as Md
from source.core.util import DoubleAnnulus , plot_vietoris_rips, drawPersistentDiagram, plot_landscapes, generate_examples
from ipywidgets import interact, IntSlider, fixed
import ripser
import teaspoon.TDA.Draw as Draw
import persim
import gudhi
from persim import PersistenceImager

# %%
r = 20
R = 40
Points = Md.Annulus(N=700, r=r, R=R, seed=None)
plot_vietoris_rips(0, Points)

# %% [markdown]
# <center>
# <h1><b>From Complex to Homology</h1>
# </center><br><br>
#
# <center>
# <img src="source/img/7.png" width="1000" height="500"/>
# </center><br><br>
#
# <center>
# <img src="source/img/8.PNG" width="700" height="200"/>
# </center>

# %% [markdown]
# <br><br>
# <center>
# <h1><b>Abelian Group Structure $\mathscr{C}_n$</h1>
# </center><br><br>
#
# <center>
# <h1><b>Formal Definition</b></h1>
# </center><br><br>
#
# <center>
# <h1>
# A Group $(G,\bullet)$ is a set $G$ with a binary operation $\bullet : G \times G \to G$ such that they follow: <br><br>
# <b>Associativity</b><br><br>
# $ (a\cdot b)\cdot c=a\cdot (b\cdot c)\hspace{10mm} \forall⁠\hspace{3mm} a⁠, b, ⁠c \in⁠ G$<br><br>
# <b>Identity element</b><br><br>
# $\exists!⁠\hspace{3mm} e \in G \hspace{5mm} \forall⁠\hspace{3mm} a\in G ⁠\hspace{10mm} e\cdot a= a = a\cdot e$<br><br>
# <b>Inverse element</b><br><br>
# $\forall⁠\hspace{3mm} a\in G ⁠\hspace{5mm}\exists!⁠\hspace{3mm} a^{-1} \in G  ⁠\hspace{10mm} a\cdot a^{-1}= e = a^{-1}\cdot a$<br><br>
# <b>Abelian Property (Conmutativity)</b><br><br>
# $\forall⁠\hspace{3mm} a,b\in G  ⁠\hspace{10mm} a\cdot b= b\cdot a$</h1>
# </center><br><br>
#
# <center>
# <h1><b>Free Generator</h1>
# </center><br><br>
#
#
# <center>
# <h2>$\displaystyle<o_1,o_2,...,o_n>=\underbrace{\mathbb{F}\oplus\mathbb{F}...\mathbb{F}\oplus\mathbb{F}}_{n-\text{times}}=\bigoplus^n \mathbb{F}\cong\mathbb{F}^n $</h2>
# </center>
# <br><br>
#
# <center>
# <img src="source/img/9.PNG" width="400" height="100"/>
# </center><br><br>
#
# <center>
# <h2>$\mathscr{C}_{n}(\mathbb{D})=\mathscr{C}(\emptyset)=\langle\emptyset\rangle\cong \mathbf{0} \hspace{2mm}(n\leqslant 0)$</h2>
# </center>
#
# <center>
# <h2>$\vdots$</h2>
# </center>
#
# <center>
# <h2>$\mathscr{C}_{-1}(\mathbb{D})=\mathscr{C}(\emptyset)=\langle\emptyset\rangle\cong \mathbf{0}$</h2>
# </center>
#
# <center>
# <h2>$\mathscr{C}_0(\mathbb{D})=\mathscr{C}(\{\{a\},\{b\},\{c\}\})=\langle\{a\},\{b\},\{c\}\rangle\cong \mathbb{Z}_2\oplus\mathbb{Z}_2\oplus\mathbb{Z}_2\cong\mathbb{Z}_2^3$</h2>
# </center>
#
# <center>
# <h2>$\mathscr{C}_1(\mathbb{D})=\mathscr{C}(\{\{a,b\},\{b,c\},\{a,c\}\})=\langle\{v_0\},\{v_1\},\{v_2\}\rangle\cong\mathbb{Z}_2\oplus\mathbb{Z}_2\oplus\mathbb{Z}_2\cong\mathbb{Z}_2^3$</h2>
# </center>
#
# <center>
# <h2>$\mathscr{C}_2(\mathbb{D})=\mathscr{C}(\{\{a,b,c\}\})=\langle f \rangle\cong \mathbb{Z}_2$</h2>
# </center>
#
# <center>
# <h2>$\mathscr{C}_{3}(\mathbb{D})=\mathscr{C}(\emptyset)=\langle\emptyset\rangle\cong \mathbf{0}$</h2>
# </center>
#
# <center>
# <h2>$\vdots$</h2>
# </center>
#
# <center>
# <h2>$\mathscr{C}_{n}(\mathbb{D})=\mathscr{C}(\emptyset)=\langle\emptyset\rangle\cong \mathbf{0} \hspace{2mm}(n\geqslant 3)$</h2>
# </center>

# %% [markdown]
# <br><br>
# <center>
# <h1><b>Boundary homomorphism $\partial_n$</h1>
# </center><br><br>
#
# <center>
# <img src="source/img/11.jpeg" width="1000" height="400"/>
# </center>

# %% [markdown]
# <center>
# <h1><b>Chain Complexes</h1>
# </center><br><br>
#
# <center>
# <h1><b>Formal Definition</b></h1>
# </center><br><br>
#
# <center>
# <h2>Sequence $( \mathscr{C},\partial )$ of abelian groups $\mathscr{C}_{n}$ (chains) and group homomorphisms $\partial_{n}$ (boundary maps) such that: $\partial_{n}\circ\partial_{n+1}=0$</h2>
# </center> <br>
#
# <center>
# <h2>${\cdots \longrightarrow \mathscr{C}_{n+1}{\stackrel {\partial_{n+1}}{\longrightarrow }}\mathscr{C}_{n}{\stackrel {\partial_{n}}{\longrightarrow }}\mathscr{C}_{n-1}{\stackrel {\partial_{n-1}}{\longrightarrow }}}\cdots$</h2>
# </center>

# %% [markdown]
# <center>
# <h1><b>Homology</b> (Finaly!!! 😂🎉)</h1>
# </center><br><br>
#
# <center>
# <h1><b>Formal Definition</b></h1>
# </center><br><br>
#
# <center>
# <h1><b>${\displaystyle n}-$th group of cycles $Z_{n}$</h1>
# </center><br>
#
# <center>
# <h2>$\displaystyle Z_{n} := \ker \partial_{n}:=\{c\in \mathscr{C}_{n}\,|\;\partial_{n}(c)=0\}$</h2>
# </center><br>
#
# <center>
# <h1><b>${\displaystyle n}-$th group of boundaries ${\displaystyle B_{n}}$</h1>
# </center><br>
#
# <center>
# <h2>${\displaystyle B_{n}:=\mathrm {im} \,\partial_{n+1}:=\{\partial_{n+1}(c)\,|\;c\in \mathscr{C}_{n+1}\}}$</h2>
# </center><br>
#
# <center>
# <h1><b>${\displaystyle n}-$th homology group ${\displaystyle H_{n}}$</h1>
# </center><br>
#
# <center>
# <h2>${\displaystyle H_{n}=Z_{n}/B_{n}} = \ker \partial_{n} / \mathrm {im} \,\partial_{n+1}$</h2>
# </center> <br>

# %% [markdown]
# <br><br>
# <center>
# <h1><b>Quotients note</b> (spoiler alert) 🚨 $\hspace{2mm}/$ is not a normal division ⚠️</h1>
# </center><br><br>
#
# <center>
# <img src="source/img/22.png" width="500" height="100"/>
# </center>
# <center>
# <img src="source/img/23.png" width="500" height="100"/>
# </center>
#
# <center>
# <img src="source/img/24.png" width="500" height="100"/>
# </center>

# %% [markdown]
# <br><br>
# <center>
# <h1><b>Homology Computation Example</b> (An easy one) 🤓</h1>
# </center><br><br>
#
# <center>
# <img src="source/img/7.png" width="1100" height="600"/>
# </center>
#
# <center>
# <h1>${\mathbf{0} {\stackrel {\partial_{3}}{\longrightarrow }} \mathbb{Z}_2 {\stackrel {\partial_{2}}{\longrightarrow }}\mathbb{Z}_2^3{\stackrel {\partial_{1}}{\longrightarrow }}\mathbb{Z}_2^3{\stackrel {\partial_{0}}{\longrightarrow }}}0$</h1>
# </center>
#
# $\hspace{8mm}$
# <center>
# <h1>$\partial_0(a)=\partial_0(b)=\partial_0(c)=0$</h1>
# </center>
#
# $\hspace{8mm}$
# <center>
# <h1>$\partial_1(v_0)=a+b$</h1>
# </center>
# <center>
# <h1>$\partial_1(v_1)=b+c$</h1>
# </center>
# <center>
# <h1>$\partial_1(v_2)=c+a$</h1>
# </center>
#
# $\hspace{8mm}$
# <center>
# <h1>$\partial_2(f)=v_0+v_1+v_2$</h1>
# </center>
#
# $\hspace{8mm}$
# <center>
# <h1>$\partial_3(0)=0$</h1>
# </center>
#
# $\hspace{8mm}$
# <center>
# <h1>${\displaystyle H_{2}(\mathbb{D})=Z_{2}/B_{2}}=\ker \partial_{2}/\mathrm {im} \,\partial_{3} = \ker \partial_{2}/\{0\} = \ker \partial_{2} =\{0\}$</h1>
# </center>
#
# $\hspace{8mm}$
# <center>
# <h1>${\displaystyle H_{1}(\mathbb{D})=Z_{1}/B_{1}}=\ker \partial_{1}/\mathrm {im} \,\partial_{2}$</h1>
# </center>
#
# $\hspace{8mm}$
# <center>
# <h1>$\displaystyle \ker \partial_{1}$</h1>
# </center>
#
# $\hspace{8mm}$
# <center>
# <h1>$\displaystyle \partial_1(c)=\alpha(a+b)+\beta(b+c)+\gamma(c+a)=0$</h1>
# </center>
#
# $\hspace{8mm}$
# <center>
# <h1>$\displaystyle \partial_1(c)=(\alpha+\gamma)a+(\alpha+\beta)b+(\beta+\gamma)c=0$</h1>
# </center>
#
# $\hspace{8mm}$
# <center>
# <h1>$\displaystyle \alpha=\beta=\gamma \because 0 \text{ or } 1$</h1>
# </center>
#
# $\hspace{8mm}$
# <center>
# <h1>$\displaystyle c=\alpha(v_0+v_1+v_2) \Rightarrow \text{spawn} (v_0+v_1+v_2)$</h1>
# </center>
#
# $\hspace{8mm}$
# <center>
# <h1>$\displaystyle \mathrm {im} \,\partial_{2} \Rightarrow \text{spawn} (v_0+v_1+v_2)$</h1>
# </center>
#
# $\hspace{8mm}$
# <center>
# <h1>$\displaystyle H_{1}(\mathbb{D})= \text{spawn} (v_0+v_1+v_2)/\text{spawn} (v_0+v_1+v_2) = \{\text{spawn} (v_0+v_1+v_2)\} \cong \{0\}$</h1>
# </center>
#
# $\hspace{8mm}$
# <center>
# <h1>${\displaystyle H_{0}(\mathbb{D})=Z_{0}/B_{0}}=\ker \partial_{0}/\mathrm {im} \,\partial_{1}$</h1>
# </center>
#
# $\hspace{8mm}$
# <center>
# <h1>$\text{dim}(\ker \partial_{0})=3$</h1>
# </center>
#
# $\hspace{8mm}$
# <center>
# <h1>$\text{dim}(\ker \partial_{1})=1 , \text{dim}(\mathbb{Z}_2^3)=3 \Rightarrow \text{dim(V)}=\text{dim}(\mathrm {im} \,\partial_{1})+\text{dim}(\ker \partial_{1}) \because  \text{dim}(\ker \partial_{1}) =2$</h1>
# </center>
#
# $\hspace{8mm}$
# <center>
# <h1>$\displaystyle \text{dim}(H_{0}(\mathbb{D}))= \text{dim}(\ker \partial_{0})- \text{dim}(\mathrm {im} \,\partial_{1})= 3-2 =1 \because H_{0}(\mathbb{D})\cong \mathbb{Z}_2$</h1>
# </center>
#
# $\hspace{8mm}$
# <center>
# <h1>$\displaystyle  H_{0}(\mathbb{D})\cong \mathbb{Z}_2 ,\hspace{4mm}  H_{1}(\mathbb{D})\cong \{0\},\hspace{4mm}   H_{2}(\mathbb{D})\cong \{0\}$</h1>
# </center>

# %% [markdown]
# <br><br>
# <center>
# <h1><b>What is Homology doing? 😵‍💫🤔</h1>
# </center><br><br>
#
#
# <center>
# <h1><b>Detecting and Counting n-dimensional holes in an Algebraic style! 🤓☝🏻</h1>
# </center><br><br>
#
#
#
# <center>
# <h1><b>But... How? and How this help us to understand data ?🤷🏻</h1>
# </center>
# <br><br>

# %% [markdown]
# <br><br>
# <center>
# <h1><b>Homology and n-dimensional holes</h1>
# </center><br><br>
#
# <center>
# <img src="source/img/12.jpeg" width="1000" height="500"/>
# </center>
#
# <br><br>
# <center>
# <h1><b>Characterization of Holes as simplexes</h1>
# </center><br><br>
#
# <center>
# <img src="source/img/13.PNG" width="1000" height="500"/>
# </center>
#
# <br><br>
# <center>
# <h1><b>$\displaystyle \text{Given} \hspace{3mm} \{p_0,...,p_k\}, \hspace{3mm} \sum_{i=0}^j \alpha_{i}v_i \hspace{5mm} \text{is a "hole"}  \Leftrightarrow \sum_{i=0}^j \alpha_{i} =0$</h1>
# </center><br><br>
#
# <center>
# <h1><b>Boundary homomorphisms codify n-boundaries and n-holes</h1>
# </center><br><br>
#
# <center>
# <img src="source/img/14.PNG" width="1000" height="500"/>
# </center>
#
# <br><br>
# <center>
# <h1><b>$\displaystyle \ker \partial_{n} \mapsto \hspace{3mm}\text{n-dim Holes}$</h1>
# </center><br><br>
#
# <br><br>
# <center>
# <h1><b>$\displaystyle \mathrm {im} \,\partial_{n+1} \mapsto \hspace{3mm}\text{n-dim Boundaries}$</h1>
# </center><br><br>
#
# <center>
# <img src="source/img/15.PNG" width="500" height="200"/>
# </center><br><br>

# %% [markdown]
# <center>
# <h1><b>How many n-holes? -> Betti Numbers</h1>
# </center><br><br>
#
#
# <center>
# <h2>Given a complex chain over a finite space $(\mathscr{C}(\mathbb{X}),\partial)$</h2>
# </center> <br><br>
#
# <center>
# <h2>$\displaystyle  H_{n}(\mathbb{X})\cong \bigoplus^k \mathbb{Z}_{2} \cong \mathbb{Z}_{2}^k $</h2>
# </center><br><br>
#
# <center>
# <h2>The n-th Betti number $\beta_n$ represents the rank of the n-th homology group (how many copies of the field)</h2>
# </center><br><br>
#
# <center>
# <h2>$\displaystyle  \beta_n (H_{n}(\mathbb{X})) = k $</h2>
# </center><br><br>
#
# <center>
# <img src="source/img/16.PNG" width="1000" height="500"/>
# </center><br><br>
#
#
# <center>
# <h1><b>Abstract Nonsense $\mapsto$ Numbers $\mapsto$ Computational Topology</h1>
# </center><br><br>
#
#
# <center>
# <img src="source/img/17.PNG" width="1000" height="500"/>
# </center><br><br>
#
# <center>
# <h1><b>Persistent Homology $\mapsto$ How the Betti numbers (Homology) behaves during different triangulations generation (on time)</h1>
# </center><br><br>
#
# <center>
# <h1><b>Filtrations</h1>
# </center><br><br>
#
# <center>
# <img src="source/img/18.PNG" width="1000" height="500"/>
# </center><br><br>
#
# <center>
# <h1><b>Filtrations Computation</h1>
# </center><br><br>
#
# <center>
# <img src="source/img/20.PNG" width="1000" height="500"/>
# </center><br><br>
#
# <center>
# <h1><b>Persistent Homology </h1>
# </center><br><br>
#
# <center>
# <img src="source/img/19.PNG" width="600" height="100"/>
# </center><br><br>
#
#
# <center>
# <h1><b>Persistent Diagrams </h1>
# </center><br><br>
#
# <center>
# <img src="source/img/27.PNG" width="600" height="100"/>
# </center><br><br>

# %% [markdown]
# <center>
# <h1><b>How to understand data then?... Let's compute some examples</b> 🤓📊📈</h1>
# </center><br><br>

# %%
r = 1
R = 2
Points = Md.Annulus(N=200, r=r, R=R, seed=None)
plot_vietoris_rips(0.4, Points)

# %%
HomologyT = ripser.ripser(Points)
DiagramsT = HomologyT['dgms']
drawPersistentDiagram(DiagramsT,2)

# %% [markdown]
# <center>
# <h1><b>Diagram congruence</b></h1>
# </center><br><br>

# %%
points_annulus1 = Md.Annulus(N=200, r=1, R=2)
points_annulus2 = Md.Annulus(N=300, r=1, R=2)
points_annulus3 = Md.Annulus(N=400, r=1, R=2)

fig, axs = plt.subplots(1, 3, figsize=(15, 5))

axs[0].scatter(points_annulus1[:, 0], points_annulus1[:, 1], color= 'blue')
axs[0].set_title('Annulus 1')
axs[0].axis('off')

axs[1].scatter(points_annulus2[:, 0], points_annulus2[:, 1], color = 'green')
axs[1].set_title('Annulus 2')
axs[1].axis('off')

axs[2].scatter(points_annulus3[:, 0], points_annulus3[:, 1], color = 'orange')
axs[2].set_title('Annulus 3')
axs[2].axis('off')
plt.tight_layout()
plt.show()

# %%
Homology1 = ripser.ripser(points_annulus1)
Diagrams1 = Homology1['dgms']
drawPersistentDiagram(Diagrams1,2)

Homology2 = ripser.ripser(points_annulus2)
Diagrams2 = Homology2['dgms']
drawPersistentDiagram(Diagrams2,2)

Homology3 = ripser.ripser(points_annulus3)
Diagrams3 = Homology3['dgms']
drawPersistentDiagram(Diagrams3,2)

# %% [markdown]
# <center>
# <h1><b>More examples</b></h1>
# </center><br><br>

# %%
Points2 = DoubleAnnulus(N1=200,N2=200,r1 = 1, R1 = 2, r2 = 0.8, R2 = 1.3, xshift = 3)
plot_vietoris_rips(0.4, Points2)

# %%
Homology2T = ripser.ripser(Points2)
Diagrams2T = Homology2T['dgms']
drawPersistentDiagram(Diagrams2T,2)

# %%
Points3 = Md.Cube(N=500)
plot_vietoris_rips(0.1, Points3)

# %%
HomologyC = ripser.ripser(Points3)
DiagramsC = HomologyC['dgms']
drawPersistentDiagram(DiagramsC,2)

# %%
Points4 = Md.Clusters(centers=np.array( [ [0,0], [0,2], [2,0]  ]), N = 400, sd = .05)
plot_vietoris_rips(0.2, Points4)

# %%
HomologyCl3 = ripser.ripser(Points4)
DiagramsCl3 = HomologyCl3['dgms']
drawPersistentDiagram(DiagramsCl3,2)

# %%
centers = np.array( [ [0,0], [0,1.5]  ])
theta = np.pi/4
centersUp = np.dot(centers,np.array([(np.sin(theta),np.cos(theta)),(np.cos(theta),-np.sin(theta))])) + [0,5]
centersUpRight = centers + [3,5]
centers = np.concatenate( (centers,  centersUp, centersUpRight))
Points5 = Md.Clusters(centers=centers, N =600, sd = .02)
plot_vietoris_rips(0.1, Points5)

# %%
HomologyClm = ripser.ripser(Points5)
DiagramsClm = HomologyClm['dgms']
drawPersistentDiagram(DiagramsClm,2)

# %% [markdown]
# <center>
# <h1><b>Metrics between diagrams 📏📐</h1>
# </center><br><br>

# %%
r = 1
R = 2
P1 = Md.Annulus(N=200, r=r, R=R) 
P2 = Md.Annulus(N=200, r=r, R=R)
P2[:,1] += 6
P3 = DoubleAnnulus()
P3 *= 1.1
P3[:,0] += 6
P3[:,1] += 3

# %%
plt.scatter(P1[:,0],P1[:,1], label = 'Torus1')
plt.scatter(P2[:,0],P2[:,1], label = 'Torus2')
plt.scatter(P3[:,0],P3[:,1], label = 'Bitorus')
plt.axis('off')
plt.legend()
plt.show()

# %%
diagrams1 = ripser.ripser(P1)['dgms']
diagrams2 = ripser.ripser(P2)['dgms']
diagrams3 = ripser.ripser(P3)['dgms']

Draw.drawDgm(diagrams1[1])
Draw.drawDgm(diagrams2[1])
Draw.drawDgm(diagrams3[1])
plt.figure(figsize=(10, 10))
plt.show()

# %% [markdown]
# <center>
# <h1><b>Bottleneck Metric</h1>
# </center><br><br>
#
# <center>
# <h2>$\displaystyle W_{\infty}(\mathscr{D},\mathscr{D}')= \inf_{\gamma : \mathscr{D}\to\mathscr{D}'}  \left(\sup_{x\in \mathscr{D}} ||x-\gamma (x)||_{\infty}\right)$</h2>
# </center><br><br>
#
# <center>
# <h1>Noise sensitive</h1>
# </center><br><br>

# %%
distance_bottleneck, x = persim.bottleneck(diagrams1[1], diagrams2[1], matching=True)
persim.visuals.bottleneck_matching(diagrams1[1], diagrams2[1], x, labels=['PTH Torus1', 'PTH Torus2'])
print('The bottleneck distance is', distance_bottleneck)
# Out:
# The bottleneck distance is 0.06193512678146362

# %%
distance_bottleneck, x = persim.bottleneck(diagrams1[1], diagrams3[1], matching=True)
persim.visuals.bottleneck_matching(diagrams1[1], diagrams3[1], x , labels=['PTH Torus1', 'PTH Bitorus'])
print('The bottleneck distance is', distance_bottleneck)
# Out:
# The bottleneck distance is 0.6498567163944244

# %% [markdown]
# <center>
# <h1><b>Wasserstein Metric</h1>
# </center><br><br>
#
# <center>
# <h2>$\displaystyle W_{p}(\mathscr{D},\mathscr{D}')= \inf_{\gamma : \mathscr{D}\to\mathscr{D}'}  \left( \sum_{x\in \mathscr{D}} ||x-\gamma (x)||_{\infty}^p \right)^{\frac{1}{p}}$</h2>
# </center><br><br>
#
# <center>
# <h1>Noise Robust</h1>
# </center><br><br>

# %%
distance_wasserstein, x = persim.wasserstein(diagrams1[1], diagrams2[1], matching=True)
persim.visuals.wasserstein_matching(diagrams1[1], diagrams2[1], x, labels=['PTH Torus1', 'PTH Torus2'])
print('The wasserstein distance is', distance_wasserstein)
# Out:
# The wasserstein distance is 0.9697792030079719

# %%
distance_wasserstein, x = persim.wasserstein(diagrams1[1], diagrams3[1], matching=True)
persim.visuals.wasserstein_matching(diagrams1[1], diagrams3[1], x , labels=['PTH Torus1', 'PTH Bitorus3'])
print('The wasserstein distance is', distance_wasserstein)
# Out:
# The wasserstein distance is 2.5640974230179103

# %% [markdown]
# <center>
# <h1><b>Lost of information due multiplicity on diagrams 📈</h1>
# </center><br><br>

# %%
Points6 = DoubleAnnulus(N1=900,N2=900,r1 = 1, R1 = 2, r2 = 1, R2 = 2, xshift = 3.8)
plt.axis('off')
plt.scatter(Points6[:,0], Points6[:,1])
plt.show()

# %%
Homology2Tm = ripser.ripser(Points6)
Diagrams2Tm = Homology2Tm['dgms']
drawPersistentDiagram(Diagrams2Tm,2)
plt.show()

# %% [markdown]
# <center>
# <h1><b>Persistence Landscapes </b>🏔️🗻</h1>
# </center><br><br>

# %%
plot_landscapes(Diagrams2Tm)

# %%
centers = np.array( [ [0,0], [0,1.5]  ])
theta = np.pi/4
centersUp = np.dot(centers,np.array([(np.sin(theta),np.cos(theta)),(np.cos(theta),-np.sin(theta))])) + [0,5]
centersUpRight = centers + [3,5]
centers = np.concatenate( (centers,  centersUp, centersUpRight))
Points5 = Md.Clusters(centers=centers, N =600, sd = .02)
plt.axis('off')
plt.scatter(Points5[:,0], Points5[:,1])
plt.show()

# %%
HomologyClm = ripser.ripser(Points5)
DiagramsClm = HomologyClm['dgms']
drawPersistentDiagram(DiagramsClm,2)

# %%
plot_landscapes(DiagramsClm,n_func=16)

# %%
Points3 = Md.Cube(N=800)
plt.axis('off')
plt.scatter(Points3[:,0],Points3[:,1])
plt.show()

# %%
HomologyC = ripser.ripser(Points3)
DiagramsC = HomologyC['dgms']
drawPersistentDiagram(DiagramsC,2)

# %%
plot_landscapes(DiagramsC,n_func=16)

# %% [markdown]
# <center>
# <h1><b>Persistence Image </b>🖼️</h1>
# </center><br><br>
#
# <center>
# <h2><b>Persistence Diagram </b></h2>
# <h2>$\displaystyle PD=\{ (b_i, d_i) \}_{i=1}^N $</h2>
# </center><br><br>
#
# <center>
# <h2><b>Persistence Transformation </b></h2>
# <h2>$\displaystyle PD_t=\{ (s_i, l_i) |\hspace{3mm} s_i=b_i+d_i \hspace{3mm},\hspace{3mm} l_i=d_i-b_i \}_{i=1}^N $</h2>
# </center><br><br>
#
# <center>
# <h2><b>Density representation </b></h2>
# <h2>$\displaystyle f_{PD_t}(s, l) = \sum_{(s_i, l_i) \in D} \delta(s-s_i, l-l_i)$</h2>
# </center><br><br>
#
# <center>
# <h2><b>Smooth with Gaussian Kernel </b></h2>
#     <h2>$\displaystyle  K_{\sigma}(s, l) = \frac{1}{2\pi\sigma^2} e^{-\frac{s^2+l^2}{2\sigma^2}}$</h2>
#
# </center><br><br>
#
#
# <center>
# <h2><b>Persistance Image</b></h2>
# <h2>$\displaystyle I(s, l) = (f_D * K_{\sigma})(s, l) = \int\int f_D(\tau_1, \tau_2) K_{\sigma}(s-\tau_1, l-\tau_2) d\tau_1 d\tau_2$</h2>
# <h2>$\displaystyle I(s, l) = \sum_{(s_i, l_i) \in D} K_{\sigma}(s-s_i, l-l_i) = \sum_{(s_i, l_i) \in D} \frac{1}{2\pi\sigma^2} e^{-\frac{(s-s_i)^2+(l-l_i)^2}{2\sigma^2}}$</h2>
# </center><br><br>
#
#
# <center>
# <img src="source/img/28.PNG" width="1000" height="500"/>
# </center><br><br>

# %%
datas = generate_examples()

# %%
rips = ripser.Rips(maxdim=1, coeff=2)
diagrams_h1 = [rips.fit_transform(data)[1] for data in datas]

plt.figure(figsize=(8,4))

plt.subplot(121)
rips.plot(diagrams_h1[0], show=False, lifetime=True)
plt.title("PD of $H_1$ for just noise")

plt.subplot(122)
rips.plot(diagrams_h1[-1], show=False, lifetime=True)
plt.title("PD of $H_1$ for circle w/ noise")

plt.show()
# Out:
# Rips(maxdim=1, thresh=inf, coeff=2, do_cocycles=False, n_perm = None, verbose=True)

# %%
pimgr = PersistenceImager(pixel_size=0.8)
pimgr.fit(diagrams_h1)
imgs = pimgr.transform(diagrams_h1)
print(f"PI Resolution = {pimgr.resolution}")

plt.figure(figsize=(12, 7))
ax = plt.subplot(121)
pimgr.plot_image(imgs[0], ax)
plt.title("PI of $H_1$ for noise")

ax = plt.subplot(122)
pimgr.plot_image(imgs[-1], ax)
plt.title("PI of $H_1$ for circle w/ noise")
# Out:
# PI Resolution = (25, 22)
# Text(0.5, 1.0, 'PI of $H_1$ for circle w/ noise')

# %% [markdown]
# <center>
# <h1><b>Euler Characteristic </b></h1>
# </center><br><br>
#
# <center>
# <img src="source/img/29.PNG" width="500" height="100"/>
# </center><br><br>
#
# <center>
# <h2>$\displaystyle  \chi =V-E+F$</h2>
# </center><br><br>
#
# <center>
# <h2>$\displaystyle  \{k_i\}_{i=0}^n \hspace{5mm}$  simplicies or $\hspace{5mm}\displaystyle  \{\beta_i\}_{i=0}^n\hspace{5mm}$ betti numbers</h2>
# <h2>$\displaystyle  \chi =\sum_{i=0}^n k_i \hspace{5mm}$ , $\hspace{5mm}\displaystyle \chi = \sum_{i=0}^n (-1)^{i} \beta_i\hspace{5mm}$ </h2>
# </center><br><br>

# %% [markdown]
# <center>
# <h1>🔎🥼🔗<b>You can acess to this material here : </b></h1>
# </center><br><br>
#
# <center>
# <img src="source/img/qr.png" width="600" height="600"/>
# </center><br><br>
